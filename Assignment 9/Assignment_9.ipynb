# %% [markdown]
# # Objective of this assignment:
#
# **integration of gradCAM**
#
# **show/visualizaion gradCAM on images**
#
# **add CutOut**
#
# **show/visualizaion gradCAM on images after adding cutOut**

# %% [markdown]
# ### Import Library

# %%
from keras import backend as K
import time
import matplotlib.pyplot as plt
import numpy as np
% matplotlib inline
np.random.seed(2017) 
from keras.models import Sequential
from keras.layers.convolutional import Convolution2D, MaxPooling2D
from keras.layers import Activation, Flatten, Dense, Dropout
from keras.layers.normalization import BatchNormalization
from keras.utils import np_utils
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### load the pre-shuffled CIFAR10 data

# %%
from keras.datasets import cifar10
(train_features, train_labels), (test_features, test_labels) = cifar10.load_data()
num_train, img_channels, img_rows, img_cols =  train_features.shape
num_test, _, _, _ =  test_features.shape
num_classes = len(np.unique(train_labels))
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 6s 0us/step

# %% [markdown]
# ### look into some images

# %%
class_names = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']
fig = plt.figure(figsize=(8,3))
for i in range(num_classes):
    ax = fig.add_subplot(2, 5, 1 + i, xticks=[], yticks=[])
    idx = np.where(train_labels[:]==i)[0]
    features_idx = train_features[idx,::]
    img_num = np.random.randint(features_idx.shape[0])
    im = features_idx[img_num]
    ax.set_title(class_names[i])
    plt.imshow(im)
plt.show()

# %% [markdown]
# ### Function to plot train and test model accuracy and losses with respect epochs

# %%
def plot_model_history(model_history):
    fig, axs = plt.subplots(1,2,figsize=(15,5))
    # summarize history for accuracy
    axs[0].plot(range(1,len(model_history.history['acc'])+1),model_history.history['acc'])
    axs[0].plot(range(1,len(model_history.history['val_acc'])+1),model_history.history['val_acc'])
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_xticks(np.arange(1,len(model_history.history['acc'])+1),len(model_history.history['acc'])/10)
    axs[0].legend(['train', 'val'], loc='best')
    # summarize history for loss
    axs[1].plot(range(1,len(model_history.history['loss'])+1),model_history.history['loss'])
    axs[1].plot(range(1,len(model_history.history['val_loss'])+1),model_history.history['val_loss'])
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    axs[1].set_xticks(np.arange(1,len(model_history.history['loss'])+1),len(model_history.history['loss'])/10)
    axs[1].legend(['train', 'val'], loc='best')
    plt.show()

# %% [markdown]
# ### Function to give actual test accuracy from model and test data

# %%
def accuracy(test_x, test_y, model):
    result = model.predict(test_x)
    predicted_class = np.argmax(result, axis=1)
    true_class = np.argmax(test_y, axis=1)
    num_correct = np.sum(predicted_class == true_class) 
    accuracy = float(num_correct)/result.shape[0]
    return (accuracy * 100)

# %%
# load dataset
(trainX, trainy), (testX, testy) = cifar10.load_data()

# %% [markdown]
# ### scale the test and train data

# %%
train_features = train_features.astype('float32')/255
test_features = test_features.astype('float32')/255

# %% [markdown]
# ### change labels from 1-dimentional class matrix to 10 dimentional class matrix to predict out of 10 class

# %%
# convert class labels to binary class labels
train_labels = np_utils.to_categorical(train_labels, num_classes)
test_labels = np_utils.to_categorical(test_labels, num_classes)

# %% [markdown]
# ### Define the model

# %%
# Define the model
model = Sequential()
model.add(Convolution2D(32, 3, 3, border_mode='same', activation='relu', input_shape=(32, 32, 3)))# RF:3
model.add(BatchNormalization())
model.add(Dropout(0.15))
model.add(Convolution2D(68, 3, 3, border_mode='same', activation='relu'))# RF:5
model.add(BatchNormalization())
model.add(Dropout(0.15))
model.add(Convolution2D(136, 3, 3, border_mode='same', activation='relu'))# RF:7
model.add(BatchNormalization())
model.add(Dropout(0.15))

model.add(Convolution2D(32, 1, 1, activation='relu')) # RF:7
model.add(MaxPooling2D(pool_size=(2, 2))) # RF:14

model.add(Convolution2D(68, 3, 3, border_mode='same', activation='relu'))# RF:16
model.add(BatchNormalization())
model.add(Dropout(0.15))
model.add(Convolution2D(136, 3, 3, border_mode='same', activation='relu'))# RF:18
model.add(BatchNormalization())
model.add(Dropout(0.15))

model.add(Convolution2D(32, 1, 1, activation='relu')) # RF:18
model.add(MaxPooling2D(pool_size=(2, 2)))# RF:36

model.add(Convolution2D(68, 3, 3, border_mode='same', activation='relu'))# RF:38
model.add(BatchNormalization())
model.add(Dropout(0.15))
model.add(Convolution2D(136, 3, 3, border_mode='same', activation='relu'))# RF:40
model.add(BatchNormalization())
model.add(Dropout(0.15))

model.add(Convolution2D(10, 1, 1, activation='relu')) # RF:40
model.add(Convolution2D(10, 8))
model.add(Flatten())
model.add(Activation('softmax'))

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), activation="relu", input_shape=(32, 32, 3..., padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(68, (3, 3), activation="relu", padding="same")`
#   """
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(136, (3, 3), activation="relu", padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (1, 1), activation="relu")`
#   if sys.path[0] == '':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:15: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(68, (3, 3), activation="relu", padding="same")`
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:18: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(136, (3, 3), activation="relu", padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:22: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (1, 1), activation="relu")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:25: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(68, (3, 3), activation="relu", padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:28: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(136, (3, 3), activation="relu", padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:32: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(10, (1, 1), activation="relu")`

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_12 (Conv2D)           (None, 32, 32, 32)        896
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 32, 32, 68)        19652
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 32, 32, 68)        272
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 32, 32, 68)        0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 32, 32, 136)       83368
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 32, 32, 136)       544
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 32, 32, 136)       0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 32, 32, 32)        4384
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 16, 16, 68)        19652
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 16, 16, 68)        272
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 16, 16, 68)        0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 16, 16, 136)       83368
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 16, 16, 136)       544
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 16, 16, 136)       0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 16, 16, 32)        4384
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 8, 8, 68)          19652
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 8, 8, 68)          272
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 8, 8, 68)          0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 8, 8, 136)         83368
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 8, 8, 136)         544
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 8, 8, 136)         0
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 8, 8, 10)          1370
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 1, 1, 10)          6410
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 10)                0
# _________________________________________________________________
# activation_2 (Activation)    (None, 10)                0
# =================================================================
# Total params: 329,080
# Trainable params: 327,792
# Non-trainable params: 1,288
# _________________________________________________________________

# %%
from keras.optimizers import Adam
from keras.callbacks import LearningRateScheduler
from keras.callbacks import ModelCheckpoint

def scheduler(epoch, lr):
  return round(0.003 * 1/(1 + 0.319 * epoch), 10)

# %% [markdown]
# ### compile the model

# %%
from keras.optimizers import Adam
model.compile(loss='categorical_crossentropy', optimizer=Adam(lr=0.003), metrics=['accuracy'])

# %% [markdown]
# ### train the model

# %%
# checkpoint
filepath="saved_model.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')

from keras.preprocessing.image import ImageDataGenerator

datagen_train = ImageDataGenerator(zoom_range=0.0,horizontal_flip=False,
                             featurewise_center=True, featurewise_std_normalization=True)

datagen_test = ImageDataGenerator(featurewise_center=True, featurewise_std_normalization=True)
iterator_test = datagen_test.flow(test_features, test_labels, batch_size=len(test_features), shuffle=False)
test_features_2, test_labels_2 = iterator_test.next()

# train the model
start = time.time()
# Train the model
model_info = model.fit_generator(datagen_train.flow(train_features, train_labels, batch_size = 256),
                                 samples_per_epoch = train_features.shape[0], nb_epoch = 100, 
                                 validation_data = (test_features_2, test_labels_2), verbose=1,
                                 callbacks=[checkpoint,LearningRateScheduler(scheduler, verbose=1)])
end = time.time()
print ("Model took %0.2f seconds to train"%(end - start))
# plot model history
plot_model_history(model_info)
# Out:
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/image/image_data_generator.py:716: UserWarning: This ImageDataGenerator specifies `featurewise_center`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/image/image_data_generator.py:724: UserWarning: This ImageDataGenerator specifies `featurewise_std_normalization`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras_pre..., validation_data=(array([[[..., verbose=1, callbacks=[<keras.ca..., steps_per_epoch=195, epochs=100)`
# Epoch 1/100
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.003.
# 195/195 [==============================] - 28s 143ms/step - loss: 0.5778 - acc: 0.8094 - val_loss: 1.0634 - val_acc: 0.6809
#
# Epoch 00001: val_acc improved from -inf to 0.68090, saving model to saved_model.hdf5
# Epoch 2/100
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.0022744503.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.3570 - acc: 0.8734 - val_loss: 0.6015 - val_acc: 0.8089
#
# Epoch 00002: val_acc improved from 0.68090 to 0.80890, saving model to saved_model.hdf5
# Epoch 3/100
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.0018315018.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.2896 - acc: 0.8949 - val_loss: 0.5962 - val_acc: 0.8126
#
# Epoch 00003: val_acc improved from 0.80890 to 0.81260, saving model to saved_model.hdf5
# Epoch 4/100
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.0015329586.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.2448 - acc: 0.9104 - val_loss: 0.7360 - val_acc: 0.7931
#
# Epoch 00004: val_acc did not improve from 0.81260
# Epoch 5/100
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.0013181019.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.2234 - acc: 0.9197 - val_loss: 0.6396 - val_acc: 0.8204
#
# Epoch 00005: val_acc improved from 0.81260 to 0.82040, saving model to saved_model.hdf5
# Epoch 6/100
#
# Epoch 00006: LearningRateScheduler setting learning rate to 0.0011560694.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.1984 - acc: 0.9278 - val_loss: 0.5988 - val_acc: 0.8300
#
# Epoch 00006: val_acc improved from 0.82040 to 0.83000, saving model to saved_model.hdf5
# Epoch 7/100
#
# Epoch 00007: LearningRateScheduler setting learning rate to 0.0010295127.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.1845 - acc: 0.9328 - val_loss: 0.6048 - val_acc: 0.8302
#
# Epoch 00007: val_acc improved from 0.83000 to 0.83020, saving model to saved_model.hdf5
# Epoch 8/100
#
# Epoch 00008: LearningRateScheduler setting learning rate to 0.0009279307.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.1738 - acc: 0.9364 - val_loss: 0.5726 - val_acc: 0.8443
#
# Epoch 00008: val_acc improved from 0.83020 to 0.84430, saving model to saved_model.hdf5
# Epoch 9/100
#
# Epoch 00009: LearningRateScheduler setting learning rate to 0.0008445946.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.1569 - acc: 0.9436 - val_loss: 0.6701 - val_acc: 0.8270
#
# Epoch 00009: val_acc did not improve from 0.84430
# Epoch 10/100
#
# Epoch 00010: LearningRateScheduler setting learning rate to 0.0007749935.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.1442 - acc: 0.9472 - val_loss: 0.6130 - val_acc: 0.8391
#
# Epoch 00010: val_acc did not improve from 0.84430
# Epoch 11/100
#
# Epoch 00011: LearningRateScheduler setting learning rate to 0.0007159905.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.1381 - acc: 0.9499 - val_loss: 0.6074 - val_acc: 0.8419
#
# Epoch 00011: val_acc did not improve from 0.84430
# Epoch 12/100
#
# Epoch 00012: LearningRateScheduler setting learning rate to 0.000665336.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.1298 - acc: 0.9530 - val_loss: 0.6850 - val_acc: 0.8292
#
# Epoch 00012: val_acc did not improve from 0.84430
# Epoch 13/100
#
# Epoch 00013: LearningRateScheduler setting learning rate to 0.0006213753.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.1276 - acc: 0.9539 - val_loss: 0.6034 - val_acc: 0.8465
#
# Epoch 00013: val_acc improved from 0.84430 to 0.84650, saving model to saved_model.hdf5
# Epoch 14/100
#
# Epoch 00014: LearningRateScheduler setting learning rate to 0.0005828638.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.1189 - acc: 0.9568 - val_loss: 0.6167 - val_acc: 0.8423
#
# Epoch 00014: val_acc did not improve from 0.84650
# Epoch 15/100
#
# Epoch 00015: LearningRateScheduler setting learning rate to 0.0005488474.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.1168 - acc: 0.9579 - val_loss: 0.6212 - val_acc: 0.8501
#
# Epoch 00015: val_acc improved from 0.84650 to 0.85010, saving model to saved_model.hdf5
# Epoch 16/100
#
# Epoch 00016: LearningRateScheduler setting learning rate to 0.0005185825.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.1122 - acc: 0.9590 - val_loss: 0.6247 - val_acc: 0.8471
#
# Epoch 00016: val_acc did not improve from 0.85010
# Epoch 17/100
#
# Epoch 00017: LearningRateScheduler setting learning rate to 0.000491481.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.1060 - acc: 0.9614 - val_loss: 0.6548 - val_acc: 0.8439
#
# Epoch 00017: val_acc did not improve from 0.85010
# Epoch 18/100
#
# Epoch 00018: LearningRateScheduler setting learning rate to 0.0004670715.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.1047 - acc: 0.9610 - val_loss: 0.6199 - val_acc: 0.8481
#
# Epoch 00018: val_acc did not improve from 0.85010
# Epoch 19/100
#
# Epoch 00019: LearningRateScheduler setting learning rate to 0.0004449718.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.1034 - acc: 0.9629 - val_loss: 0.6165 - val_acc: 0.8505
#
# Epoch 00019: val_acc improved from 0.85010 to 0.85050, saving model to saved_model.hdf5
# Epoch 20/100
#
# Epoch 00020: LearningRateScheduler setting learning rate to 0.000424869.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.0987 - acc: 0.9645 - val_loss: 0.6409 - val_acc: 0.8485
#
# Epoch 00020: val_acc did not improve from 0.85050
# Epoch 21/100
#
# Epoch 00021: LearningRateScheduler setting learning rate to 0.0004065041.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.0959 - acc: 0.9644 - val_loss: 0.6627 - val_acc: 0.8488
#
# Epoch 00021: val_acc did not improve from 0.85050
# Epoch 22/100
#
# Epoch 00022: LearningRateScheduler setting learning rate to 0.000389661.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.0941 - acc: 0.9663 - val_loss: 0.6448 - val_acc: 0.8475
#
# Epoch 00022: val_acc did not improve from 0.85050
# Epoch 23/100
#
# Epoch 00023: LearningRateScheduler setting learning rate to 0.0003741581.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.0936 - acc: 0.9663 - val_loss: 0.6610 - val_acc: 0.8476
#
# Epoch 00023: val_acc did not improve from 0.85050
# Epoch 24/100
#
# Epoch 00024: LearningRateScheduler setting learning rate to 0.0003598417.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.0884 - acc: 0.9675 - val_loss: 0.6434 - val_acc: 0.8534
#
# Epoch 00024: val_acc improved from 0.85050 to 0.85340, saving model to saved_model.hdf5
# Epoch 25/100
#
# Epoch 00025: LearningRateScheduler setting learning rate to 0.0003465804.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.0878 - acc: 0.9676 - val_loss: 0.6675 - val_acc: 0.8524
#
# Epoch 00025: val_acc did not improve from 0.85340
# Epoch 26/100
#
# Epoch 00026: LearningRateScheduler setting learning rate to 0.0003342618.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.0863 - acc: 0.9687 - val_loss: 0.6716 - val_acc: 0.8482
#
# Epoch 00026: val_acc did not improve from 0.85340
# Epoch 27/100
#
# Epoch 00027: LearningRateScheduler setting learning rate to 0.0003227889.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.0800 - acc: 0.9721 - val_loss: 0.6701 - val_acc: 0.8485
#
# Epoch 00027: val_acc did not improve from 0.85340
# Epoch 28/100
#
# Epoch 00028: LearningRateScheduler setting learning rate to 0.0003120774.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.0818 - acc: 0.9707 - val_loss: 0.6684 - val_acc: 0.8504
#
# Epoch 00028: val_acc did not improve from 0.85340
# Epoch 29/100
#
# Epoch 00029: LearningRateScheduler setting learning rate to 0.000302054.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.0780 - acc: 0.9720 - val_loss: 0.6744 - val_acc: 0.8508
#
# Epoch 00029: val_acc did not improve from 0.85340
# Epoch 30/100
#
# Epoch 00030: LearningRateScheduler setting learning rate to 0.0002926544.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.0808 - acc: 0.9708 - val_loss: 0.6610 - val_acc: 0.8526
#
# Epoch 00030: val_acc did not improve from 0.85340
# Epoch 31/100
#
# Epoch 00031: LearningRateScheduler setting learning rate to 0.0002838221.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.0791 - acc: 0.9713 - val_loss: 0.6588 - val_acc: 0.8543
#
# Epoch 00031: val_acc improved from 0.85340 to 0.85430, saving model to saved_model.hdf5
# Epoch 32/100
#
# Epoch 00032: LearningRateScheduler setting learning rate to 0.0002755074.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.0747 - acc: 0.9732 - val_loss: 0.6602 - val_acc: 0.8535
#
# Epoch 00032: val_acc did not improve from 0.85430
# Epoch 33/100
#
# Epoch 00033: LearningRateScheduler setting learning rate to 0.000267666.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.0761 - acc: 0.9721 - val_loss: 0.6640 - val_acc: 0.8515
#
# Epoch 00033: val_acc did not improve from 0.85430
# Epoch 34/100
#
# Epoch 00034: LearningRateScheduler setting learning rate to 0.0002602585.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.0726 - acc: 0.9731 - val_loss: 0.6771 - val_acc: 0.8510
#
# Epoch 00034: val_acc did not improve from 0.85430
# Epoch 35/100
#
# Epoch 00035: LearningRateScheduler setting learning rate to 0.00025325.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.0702 - acc: 0.9738 - val_loss: 0.6739 - val_acc: 0.8525
#
# Epoch 00035: val_acc did not improve from 0.85430
# Epoch 36/100
#
# Epoch 00036: LearningRateScheduler setting learning rate to 0.0002466091.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.0709 - acc: 0.9740 - val_loss: 0.6688 - val_acc: 0.8560
#
# Epoch 00036: val_acc improved from 0.85430 to 0.85600, saving model to saved_model.hdf5
# Epoch 37/100
#
# Epoch 00037: LearningRateScheduler setting learning rate to 0.0002403076.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.0704 - acc: 0.9752 - val_loss: 0.6632 - val_acc: 0.8573
#
# Epoch 00037: val_acc improved from 0.85600 to 0.85730, saving model to saved_model.hdf5
# Epoch 38/100
#
# Epoch 00038: LearningRateScheduler setting learning rate to 0.0002343201.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.0696 - acc: 0.9756 - val_loss: 0.6755 - val_acc: 0.8552
#
# Epoch 00038: val_acc did not improve from 0.85730
# Epoch 39/100
#
# Epoch 00039: LearningRateScheduler setting learning rate to 0.0002286237.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.0695 - acc: 0.9746 - val_loss: 0.6710 - val_acc: 0.8539
#
# Epoch 00039: val_acc did not improve from 0.85730
# Epoch 40/100
#
# Epoch 00040: LearningRateScheduler setting learning rate to 0.0002231977.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.0676 - acc: 0.9752 - val_loss: 0.6829 - val_acc: 0.8541
#
# Epoch 00040: val_acc did not improve from 0.85730
# Epoch 41/100
#
# Epoch 00041: LearningRateScheduler setting learning rate to 0.0002180233.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.0641 - acc: 0.9765 - val_loss: 0.6849 - val_acc: 0.8529
#
# Epoch 00041: val_acc did not improve from 0.85730
# Epoch 42/100
#
# Epoch 00042: LearningRateScheduler setting learning rate to 0.0002130833.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.0658 - acc: 0.9767 - val_loss: 0.6911 - val_acc: 0.8529
#
# Epoch 00042: val_acc did not improve from 0.85730
# Epoch 43/100
#
# Epoch 00043: LearningRateScheduler setting learning rate to 0.0002083623.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.0637 - acc: 0.9770 - val_loss: 0.6905 - val_acc: 0.8540
#
# Epoch 00043: val_acc did not improve from 0.85730
# Epoch 44/100
#
# Epoch 00044: LearningRateScheduler setting learning rate to 0.0002038459.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.0638 - acc: 0.9768 - val_loss: 0.6865 - val_acc: 0.8534
#
# Epoch 00044: val_acc did not improve from 0.85730
# Epoch 45/100
#
# Epoch 00045: LearningRateScheduler setting learning rate to 0.0001995211.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.0683 - acc: 0.9755 - val_loss: 0.6863 - val_acc: 0.8533
#
# Epoch 00045: val_acc did not improve from 0.85730
# Epoch 46/100
#
# Epoch 00046: LearningRateScheduler setting learning rate to 0.0001953761.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.0624 - acc: 0.9774 - val_loss: 0.7040 - val_acc: 0.8529
#
# Epoch 00046: val_acc did not improve from 0.85730
# Epoch 47/100
#
# Epoch 00047: LearningRateScheduler setting learning rate to 0.0001913998.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.0618 - acc: 0.9771 - val_loss: 0.6875 - val_acc: 0.8540
#
# Epoch 00047: val_acc did not improve from 0.85730
# Epoch 48/100
#
# Epoch 00048: LearningRateScheduler setting learning rate to 0.0001875821.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.0612 - acc: 0.9775 - val_loss: 0.6914 - val_acc: 0.8562
#
# Epoch 00048: val_acc did not improve from 0.85730
# Epoch 49/100
#
# Epoch 00049: LearningRateScheduler setting learning rate to 0.0001839137.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.0616 - acc: 0.9780 - val_loss: 0.7066 - val_acc: 0.8499
#
# Epoch 00049: val_acc did not improve from 0.85730
# Epoch 50/100
#
# Epoch 00050: LearningRateScheduler setting learning rate to 0.000180386.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.0569 - acc: 0.9798 - val_loss: 0.6917 - val_acc: 0.8546
#
# Epoch 00050: val_acc did not improve from 0.85730
# Epoch 51/100
#
# Epoch 00051: LearningRateScheduler setting learning rate to 0.0001769912.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.0597 - acc: 0.9790 - val_loss: 0.6889 - val_acc: 0.8577
#
# Epoch 00051: val_acc improved from 0.85730 to 0.85770, saving model to saved_model.hdf5
# Epoch 52/100
#
# Epoch 00052: LearningRateScheduler setting learning rate to 0.0001737217.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.0575 - acc: 0.9795 - val_loss: 0.6901 - val_acc: 0.8579
#
# Epoch 00052: val_acc improved from 0.85770 to 0.85790, saving model to saved_model.hdf5
# Epoch 53/100
#
# Epoch 00053: LearningRateScheduler setting learning rate to 0.0001705708.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.0586 - acc: 0.9794 - val_loss: 0.6966 - val_acc: 0.8559
#
# Epoch 00053: val_acc did not improve from 0.85790
# Epoch 54/100
#
# Epoch 00054: LearningRateScheduler setting learning rate to 0.0001675322.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.0579 - acc: 0.9794 - val_loss: 0.7084 - val_acc: 0.8545
#
# Epoch 00054: val_acc did not improve from 0.85790
# Epoch 55/100
#
# Epoch 00055: LearningRateScheduler setting learning rate to 0.0001646.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.0559 - acc: 0.9804 - val_loss: 0.6958 - val_acc: 0.8544
#
# Epoch 00055: val_acc did not improve from 0.85790
# Epoch 56/100
#
# Epoch 00056: LearningRateScheduler setting learning rate to 0.0001617687.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.0597 - acc: 0.9787 - val_loss: 0.7068 - val_acc: 0.8549
#
# Epoch 00056: val_acc did not improve from 0.85790
# Epoch 57/100
#
# Epoch 00057: LearningRateScheduler setting learning rate to 0.0001590331.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.0555 - acc: 0.9803 - val_loss: 0.7035 - val_acc: 0.8557
#
# Epoch 00057: val_acc did not improve from 0.85790
# Epoch 58/100
#
# Epoch 00058: LearningRateScheduler setting learning rate to 0.0001563885.
# 195/195 [==============================] - 28s 141ms/step - loss: 0.0571 - acc: 0.9806 - val_loss: 0.7019 - val_acc: 0.8537
#
# Epoch 00058: val_acc did not improve from 0.85790
# Epoch 59/100
#
# Epoch 00059: LearningRateScheduler setting learning rate to 0.0001538304.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.0550 - acc: 0.9806 - val_loss: 0.6982 - val_acc: 0.8543
#
# Epoch 00059: val_acc did not improve from 0.85790
# Epoch 60/100
#
# Epoch 00060: LearningRateScheduler setting learning rate to 0.0001513546.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.0564 - acc: 0.9799 - val_loss: 0.7126 - val_acc: 0.8555
#
# Epoch 00060: val_acc did not improve from 0.85790
# Epoch 61/100
#
# Epoch 00061: LearningRateScheduler setting learning rate to 0.0001489573.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.0542 - acc: 0.9808 - val_loss: 0.6987 - val_acc: 0.8555
#
# Epoch 00061: val_acc did not improve from 0.85790
# Epoch 62/100
#
# Epoch 00062: LearningRateScheduler setting learning rate to 0.0001466347.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.0555 - acc: 0.9801 - val_loss: 0.7125 - val_acc: 0.8558
#
# Epoch 00062: val_acc did not improve from 0.85790
# Epoch 63/100
#
# Epoch 00063: LearningRateScheduler setting learning rate to 0.0001443835.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.0539 - acc: 0.9800 - val_loss: 0.7100 - val_acc: 0.8544
#
# Epoch 00063: val_acc did not improve from 0.85790
# Epoch 64/100
#
# Epoch 00064: LearningRateScheduler setting learning rate to 0.0001422003.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.0549 - acc: 0.9806 - val_loss: 0.7066 - val_acc: 0.8520
#
# Epoch 00064: val_acc did not improve from 0.85790
# Epoch 65/100
#
# Epoch 00065: LearningRateScheduler setting learning rate to 0.0001400822.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.0538 - acc: 0.9804 - val_loss: 0.7193 - val_acc: 0.8537
#
# Epoch 00065: val_acc did not improve from 0.85790
# Epoch 66/100
#
# Epoch 00066: LearningRateScheduler setting learning rate to 0.0001380262.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.0527 - acc: 0.9810 - val_loss: 0.7024 - val_acc: 0.8560
#
# Epoch 00066: val_acc did not improve from 0.85790
# Epoch 67/100
#
# Epoch 00067: LearningRateScheduler setting learning rate to 0.0001360297.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.0529 - acc: 0.9810 - val_loss: 0.7178 - val_acc: 0.8523
#
# Epoch 00067: val_acc did not improve from 0.85790
# Epoch 68/100
#
# Epoch 00068: LearningRateScheduler setting learning rate to 0.0001340902.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.0520 - acc: 0.9813 - val_loss: 0.7144 - val_acc: 0.8556
#
# Epoch 00068: val_acc did not improve from 0.85790
# Epoch 69/100
#
# Epoch 00069: LearningRateScheduler setting learning rate to 0.0001322052.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.0532 - acc: 0.9811 - val_loss: 0.7314 - val_acc: 0.8543
#
# Epoch 00069: val_acc did not improve from 0.85790
# Epoch 70/100
#
# Epoch 00070: LearningRateScheduler setting learning rate to 0.0001303724.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.0516 - acc: 0.9805 - val_loss: 0.7258 - val_acc: 0.8545
#
# Epoch 00070: val_acc did not improve from 0.85790
# Epoch 71/100
#
# Epoch 00071: LearningRateScheduler setting learning rate to 0.0001285898.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.0508 - acc: 0.9818 - val_loss: 0.7208 - val_acc: 0.8539
#
# Epoch 00071: val_acc did not improve from 0.85790
# Epoch 72/100
#
# Epoch 00072: LearningRateScheduler setting learning rate to 0.0001268553.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.0531 - acc: 0.9805 - val_loss: 0.7329 - val_acc: 0.8552
#
# Epoch 00072: val_acc did not improve from 0.85790
# Epoch 73/100
#
# Epoch 00073: LearningRateScheduler setting learning rate to 0.0001251669.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.0502 - acc: 0.9822 - val_loss: 0.7251 - val_acc: 0.8536
#
# Epoch 00073: val_acc did not improve from 0.85790
# Epoch 74/100
#
# Epoch 00074: LearningRateScheduler setting learning rate to 0.0001235229.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.0516 - acc: 0.9815 - val_loss: 0.7229 - val_acc: 0.8525
#
# Epoch 00074: val_acc did not improve from 0.85790
# Epoch 75/100
#
# Epoch 00075: LearningRateScheduler setting learning rate to 0.0001219215.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.0474 - acc: 0.9832 - val_loss: 0.7369 - val_acc: 0.8557
#
# Epoch 00075: val_acc did not improve from 0.85790
# Epoch 76/100
#
# Epoch 00076: LearningRateScheduler setting learning rate to 0.0001203611.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.0504 - acc: 0.9813 - val_loss: 0.7340 - val_acc: 0.8560
#
# Epoch 00076: val_acc did not improve from 0.85790
# Epoch 77/100
#
# Epoch 00077: LearningRateScheduler setting learning rate to 0.0001188401.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.0497 - acc: 0.9820 - val_loss: 0.7182 - val_acc: 0.8582
#
# Epoch 00077: val_acc improved from 0.85790 to 0.85820, saving model to saved_model.hdf5
# Epoch 78/100
#
# Epoch 00078: LearningRateScheduler setting learning rate to 0.0001173571.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.0482 - acc: 0.9826 - val_loss: 0.7359 - val_acc: 0.8543
#
# Epoch 00078: val_acc did not improve from 0.85820
# Epoch 79/100
#
# Epoch 00079: LearningRateScheduler setting learning rate to 0.0001159107.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.0507 - acc: 0.9823 - val_loss: 0.7304 - val_acc: 0.8554
#
# Epoch 00079: val_acc did not improve from 0.85820
# Epoch 80/100
#
# Epoch 00080: LearningRateScheduler setting learning rate to 0.0001144994.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.0484 - acc: 0.9829 - val_loss: 0.7273 - val_acc: 0.8543
#
# Epoch 00080: val_acc did not improve from 0.85820
# Epoch 81/100
#
# Epoch 00081: LearningRateScheduler setting learning rate to 0.0001131222.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.0490 - acc: 0.9831 - val_loss: 0.7310 - val_acc: 0.8560
#
# Epoch 00081: val_acc did not improve from 0.85820
# Epoch 82/100
#
# Epoch 00082: LearningRateScheduler setting learning rate to 0.0001117776.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.0493 - acc: 0.9824 - val_loss: 0.7231 - val_acc: 0.8560
#
# Epoch 00082: val_acc did not improve from 0.85820
# Epoch 83/100
#
# Epoch 00083: LearningRateScheduler setting learning rate to 0.0001104647.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.0473 - acc: 0.9827 - val_loss: 0.7310 - val_acc: 0.8560
#
# Epoch 00083: val_acc did not improve from 0.85820
# Epoch 84/100
#
# Epoch 00084: LearningRateScheduler setting learning rate to 0.0001091822.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.0485 - acc: 0.9826 - val_loss: 0.7288 - val_acc: 0.8546
#
# Epoch 00084: val_acc did not improve from 0.85820
# Epoch 85/100
#
# Epoch 00085: LearningRateScheduler setting learning rate to 0.0001079292.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.0465 - acc: 0.9835 - val_loss: 0.7311 - val_acc: 0.8563
#
# Epoch 00085: val_acc did not improve from 0.85820
# Epoch 86/100
#
# Epoch 00086: LearningRateScheduler setting learning rate to 0.0001067046.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.0463 - acc: 0.9833 - val_loss: 0.7256 - val_acc: 0.8562
#
# Epoch 00086: val_acc did not improve from 0.85820
# Epoch 87/100
#
# Epoch 00087: LearningRateScheduler setting learning rate to 0.0001055075.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.0479 - acc: 0.9825 - val_loss: 0.7312 - val_acc: 0.8561
#
# Epoch 00087: val_acc did not improve from 0.85820
# Epoch 88/100
#
# Epoch 00088: LearningRateScheduler setting learning rate to 0.0001043369.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.0470 - acc: 0.9827 - val_loss: 0.7302 - val_acc: 0.8568
#
# Epoch 00088: val_acc did not improve from 0.85820
# Epoch 89/100
#
# Epoch 00089: LearningRateScheduler setting learning rate to 0.0001031921.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.0482 - acc: 0.9831 - val_loss: 0.7259 - val_acc: 0.8573
#
# Epoch 00089: val_acc did not improve from 0.85820
# Epoch 90/100
#
# Epoch 00090: LearningRateScheduler setting learning rate to 0.0001020721.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.0490 - acc: 0.9827 - val_loss: 0.7333 - val_acc: 0.8580
#
# Epoch 00090: val_acc did not improve from 0.85820
# Epoch 91/100
#
# Epoch 00091: LearningRateScheduler setting learning rate to 0.0001009761.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.0458 - acc: 0.9837 - val_loss: 0.7303 - val_acc: 0.8561
#
# Epoch 00091: val_acc did not improve from 0.85820
# Epoch 92/100
#
# Epoch 00092: LearningRateScheduler setting learning rate to 9.99034e-05.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.0455 - acc: 0.9840 - val_loss: 0.7244 - val_acc: 0.8583
#
# Epoch 00092: val_acc improved from 0.85820 to 0.85830, saving model to saved_model.hdf5
# Epoch 93/100
#
# Epoch 00093: LearningRateScheduler setting learning rate to 9.88533e-05.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.0450 - acc: 0.9842 - val_loss: 0.7339 - val_acc: 0.8559
#
# Epoch 00093: val_acc did not improve from 0.85830
# Epoch 94/100
#
# Epoch 00094: LearningRateScheduler setting learning rate to 9.7825e-05.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.0458 - acc: 0.9832 - val_loss: 0.7345 - val_acc: 0.8562
#
# Epoch 00094: val_acc did not improve from 0.85830
# Epoch 95/100
#
# Epoch 00095: LearningRateScheduler setting learning rate to 9.68179e-05.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.0450 - acc: 0.9837 - val_loss: 0.7329 - val_acc: 0.8565
#
# Epoch 00095: val_acc did not improve from 0.85830
# Epoch 96/100
#
# Epoch 00096: LearningRateScheduler setting learning rate to 9.58313e-05.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.0440 - acc: 0.9840 - val_loss: 0.7318 - val_acc: 0.8563
#
# Epoch 00096: val_acc did not improve from 0.85830
# Epoch 97/100
#
# Epoch 00097: LearningRateScheduler setting learning rate to 9.48647e-05.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.0478 - acc: 0.9830 - val_loss: 0.7396 - val_acc: 0.8546
#
# Epoch 00097: val_acc did not improve from 0.85830
# Epoch 98/100
#
# Epoch 00098: LearningRateScheduler setting learning rate to 9.39173e-05.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.0455 - acc: 0.9843 - val_loss: 0.7299 - val_acc: 0.8559
#
# Epoch 00098: val_acc did not improve from 0.85830
# Epoch 99/100
#
# Epoch 00099: LearningRateScheduler setting learning rate to 9.29887e-05.
# 195/195 [==============================] - 28s 141ms/step - loss: 0.0453 - acc: 0.9845 - val_loss: 0.7274 - val_acc: 0.8582
#
# Epoch 00099: val_acc did not improve from 0.85830
# Epoch 100/100
#
# Epoch 00100: LearningRateScheduler setting learning rate to 9.20782e-05.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.0469 - acc: 0.9831 - val_loss: 0.7293 - val_acc: 0.8566
#
# Epoch 00100: val_acc did not improve from 0.85830
# Model took 2770.09 seconds to train

# %%
score = model.evaluate(test_features, test_labels, batch_size=128)
print (score[1])
# Out:
# 10000/10000 [==============================] - 2s 197us/step
# 0.8566

# %% [markdown]
# ## Grad CAM result without Cutout

# %%
import cv2
from google.colab.patches import cv2_imshow

images = [100,101,201,510,600,1000,1600,1601,3000,4000,5500,7000,7500,8000,9000,9999]
for j in images:
  x = testX[j]
  x = np.expand_dims(x, axis=0)
  preds = model.predict(x,batch_size=1)
  class_idx = np.argmax(preds[0])
  class_output = model.output[:, class_idx]
  last_conv_layer = model.get_layer("conv2d_20")

  grads = K.gradients(class_output, last_conv_layer.output)[0]
  pooled_grads = K.mean(grads, axis=(0, 1, 2))
  iterate = K.function([model.input], [pooled_grads, last_conv_layer.output[0]])
  pooled_grads_value, conv_layer_output_value = iterate([x])
  for i in range(136):
    conv_layer_output_value[:, :, i] *= pooled_grads_value[i]
  
  heatmap = np.mean(conv_layer_output_value, axis=-1)
  heatmap = np.maximum(heatmap, 0)
  heatmap /= np.max(heatmap) 
  img = (testX[j])
  heatmap = cv2.resize(heatmap, (img.shape[1], img.shape[0]))
  heatmap = np.uint8(255 * heatmap)
  heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)
  superimposed_img = cv2.addWeighted(img, 0.6, heatmap, 0.4, 0)
  
  #cv2_imshow(img)
  #cv2_imshow(superimposed_img)
  concatimg = cv2.hconcat([img,superimposed_img])
  # Display the concatenated image
  print (j)
  cv2_imshow(concatimg)
  cv2.waitKey(0)
  print (" ")
  j = j + 1
# Out:
# 100
# <PIL.Image.Image image mode=RGB size=64x32 at 0x7FD317A8DEF0>
#
# 101
# <PIL.Image.Image image mode=RGB size=64x32 at 0x7FD3179C64E0>
#
# 201
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:22: RuntimeWarning: invalid value encountered in true_divide
# <PIL.Image.Image image mode=RGB size=64x32 at 0x7FD3178EC9B0>
#
# 510
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:22: RuntimeWarning: invalid value encountered in true_divide
# <PIL.Image.Image image mode=RGB size=64x32 at 0x7FD317A9DD68>
#
# 600
# <PIL.Image.Image image mode=RGB size=64x32 at 0x7FD3177BDFD0>
#
# 1000
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:22: RuntimeWarning: invalid value encountered in true_divide
# <PIL.Image.Image image mode=RGB size=64x32 at 0x7FD317A9DD68>
#
# 1600
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:22: RuntimeWarning: invalid value encountered in true_divide
# <PIL.Image.Image image mode=RGB size=64x32 at 0x7FD31769F6A0>
#
# 1601
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:22: RuntimeWarning: invalid value encountered in true_divide
# <PIL.Image.Image image mode=RGB size=64x32 at 0x7FD317A9DD68>
#
# 3000
# <PIL.Image.Image image mode=RGB size=64x32 at 0x7FD31775FFD0>
#
# 4000
# <PIL.Image.Image image mode=RGB size=64x32 at 0x7FD317A9DD68>
#
# 5500
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:22: RuntimeWarning: invalid value encountered in true_divide
# <PIL.Image.Image image mode=RGB size=64x32 at 0x7FD3177A9EB8>
#
# 7000
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:22: RuntimeWarning: invalid value encountered in true_divide
# <PIL.Image.Image image mode=RGB size=64x32 at 0x7FD3175029E8>
#
# 7500
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:22: RuntimeWarning: invalid value encountered in true_divide
# <PIL.Image.Image image mode=RGB size=64x32 at 0x7FD3174A4D68>
#
# 8000
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:22: RuntimeWarning: invalid value encountered in true_divide
# <PIL.Image.Image image mode=RGB size=64x32 at 0x7FD3174A4D68>
#
# 9000
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:22: RuntimeWarning: invalid value encountered in true_divide
# <PIL.Image.Image image mode=RGB size=64x32 at 0x7FD3174A4D68>
#
# 9999
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:22: RuntimeWarning: invalid value encountered in true_divide
# <PIL.Image.Image image mode=RGB size=64x32 at 0x7FD3174A4D68>

# %% [markdown]
# **Assignment Part2:**

# %% [markdown]
# ## Cutout

# %%
def get_random_eraser(p=0.5, s_l=0.02, s_h=0.4, r_1=0.3, r_2=1/0.3, v_l=0, v_h=255, pixel_level=False):
    def eraser(input_img):
        img_h, img_w, img_c = input_img.shape
        p_1 = np.random.rand()

        if p_1 > p:
            return input_img

        while True:
            s = np.random.uniform(s_l, s_h) * img_h * img_w
            r = np.random.uniform(r_1, r_2)
            w = int(np.sqrt(s / r))
            h = int(np.sqrt(s * r))
            left = np.random.randint(0, img_w)
            top = np.random.randint(0, img_h)

            if left + w <= img_w and top + h <= img_h:
                break

        if pixel_level:
            c = np.random.uniform(v_l, v_h, (h, w, img_c))
        else:
            c = np.random.uniform(v_l, v_h)

        input_img[top:top + h, left:left + w, :] = c

        return input_img

    return eraser

# %% [markdown]
# ### Model with Cutout

# %%
# checkpoint
filepath="saved_model.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')

from keras.preprocessing.image import ImageDataGenerator

datagen_train = ImageDataGenerator(zoom_range=0.0,horizontal_flip=False,
                             featurewise_center=True, featurewise_std_normalization=True,preprocessing_function=get_random_eraser(v_l=0, v_h=1, pixel_level=True))

datagen_test = ImageDataGenerator(featurewise_center=True, featurewise_std_normalization=True)
iterator_test = datagen_test.flow(test_features, test_labels, batch_size=len(test_features), shuffle=False)
test_features_2, test_labels_2 = iterator_test.next()

# train the model
start = time.time()
# Train the model
model_info = model.fit_generator(datagen_train.flow(train_features, train_labels, batch_size = 256),
                                 samples_per_epoch = train_features.shape[0], nb_epoch = 100, 
                                 validation_data = (test_features_2, test_labels_2), verbose=1,
                                 callbacks=[checkpoint,LearningRateScheduler(scheduler, verbose=1)])
end = time.time()
print ("Model took %0.2f seconds to train"%(end - start))
# plot model history
plot_model_history(model_info)
# Out:
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/image/image_data_generator.py:716: UserWarning: This ImageDataGenerator specifies `featurewise_center`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/image/image_data_generator.py:724: UserWarning: This ImageDataGenerator specifies `featurewise_std_normalization`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras_pre..., validation_data=(array([[[..., verbose=1, callbacks=[<keras.ca..., steps_per_epoch=195, epochs=100)`
# Epoch 1/100
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.003.
# 195/195 [==============================] - 29s 146ms/step - loss: 0.7843 - acc: 0.7428 - val_loss: 0.7953 - val_acc: 0.7465
#
# Epoch 00001: val_acc improved from -inf to 0.74650, saving model to saved_model.hdf5
# Epoch 2/100
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.0022744503.
# 195/195 [==============================] - 28s 143ms/step - loss: 0.4991 - acc: 0.8246 - val_loss: 0.5984 - val_acc: 0.8163
#
# Epoch 00002: val_acc improved from 0.74650 to 0.81630, saving model to saved_model.hdf5
# Epoch 3/100
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.0018315018.
# 195/195 [==============================] - 28s 143ms/step - loss: 0.4222 - acc: 0.8493 - val_loss: 0.6065 - val_acc: 0.8038
#
# Epoch 00003: val_acc did not improve from 0.81630
# Epoch 4/100
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.0015329586.
# 195/195 [==============================] - 28s 143ms/step - loss: 0.3865 - acc: 0.8623 - val_loss: 0.5244 - val_acc: 0.8396
#
# Epoch 00004: val_acc improved from 0.81630 to 0.83960, saving model to saved_model.hdf5
# Epoch 5/100
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.0013181019.
# 195/195 [==============================] - 28s 143ms/step - loss: 0.3560 - acc: 0.8727 - val_loss: 0.5419 - val_acc: 0.8355
#
# Epoch 00005: val_acc did not improve from 0.83960
# Epoch 6/100
#
# Epoch 00006: LearningRateScheduler setting learning rate to 0.0011560694.
# 195/195 [==============================] - 28s 143ms/step - loss: 0.3309 - acc: 0.8807 - val_loss: 0.5680 - val_acc: 0.8304
#
# Epoch 00006: val_acc did not improve from 0.83960
# Epoch 7/100
#
# Epoch 00007: LearningRateScheduler setting learning rate to 0.0010295127.
# 195/195 [==============================] - 28s 143ms/step - loss: 0.3119 - acc: 0.8876 - val_loss: 0.5177 - val_acc: 0.8464
#
# Epoch 00007: val_acc improved from 0.83960 to 0.84640, saving model to saved_model.hdf5
# Epoch 8/100
#
# Epoch 00008: LearningRateScheduler setting learning rate to 0.0009279307.
# 195/195 [==============================] - 28s 143ms/step - loss: 0.3108 - acc: 0.8891 - val_loss: 0.5198 - val_acc: 0.8432
#
# Epoch 00008: val_acc did not improve from 0.84640
# Epoch 9/100
#
# Epoch 00009: LearningRateScheduler setting learning rate to 0.0008445946.
# 195/195 [==============================] - 28s 143ms/step - loss: 0.2962 - acc: 0.8956 - val_loss: 0.5213 - val_acc: 0.8459
#
# Epoch 00009: val_acc did not improve from 0.84640
# Epoch 10/100
#
# Epoch 00010: LearningRateScheduler setting learning rate to 0.0007749935.
# 195/195 [==============================] - 28s 143ms/step - loss: 0.2893 - acc: 0.8979 - val_loss: 0.5124 - val_acc: 0.8526
#
# Epoch 00010: val_acc improved from 0.84640 to 0.85260, saving model to saved_model.hdf5
# Epoch 11/100
#
# Epoch 00011: LearningRateScheduler setting learning rate to 0.0007159905.
# 195/195 [==============================] - 28s 143ms/step - loss: 0.2728 - acc: 0.9028 - val_loss: 0.5215 - val_acc: 0.8502
#
# Epoch 00011: val_acc did not improve from 0.85260
# Epoch 12/100
#
# Epoch 00012: LearningRateScheduler setting learning rate to 0.000665336.
# 195/195 [==============================] - 28s 143ms/step - loss: 0.2706 - acc: 0.9044 - val_loss: 0.5241 - val_acc: 0.8467
#
# Epoch 00012: val_acc did not improve from 0.85260
# Epoch 13/100
#
# Epoch 00013: LearningRateScheduler setting learning rate to 0.0006213753.
# 195/195 [==============================] - 28s 143ms/step - loss: 0.2599 - acc: 0.9087 - val_loss: 0.5139 - val_acc: 0.8542
#
# Epoch 00013: val_acc improved from 0.85260 to 0.85420, saving model to saved_model.hdf5
# Epoch 14/100
#
# Epoch 00014: LearningRateScheduler setting learning rate to 0.0005828638.
# 195/195 [==============================] - 28s 143ms/step - loss: 0.2586 - acc: 0.9091 - val_loss: 0.5244 - val_acc: 0.8511
#
# Epoch 00014: val_acc did not improve from 0.85420
# Epoch 15/100
#
# Epoch 00015: LearningRateScheduler setting learning rate to 0.0005488474.
# 195/195 [==============================] - 28s 143ms/step - loss: 0.2504 - acc: 0.9110 - val_loss: 0.5118 - val_acc: 0.8540
#
# Epoch 00015: val_acc did not improve from 0.85420
# Epoch 16/100
#
# Epoch 00016: LearningRateScheduler setting learning rate to 0.0005185825.
# 195/195 [==============================] - 28s 143ms/step - loss: 0.2412 - acc: 0.9143 - val_loss: 0.5175 - val_acc: 0.8543
#
# Epoch 00016: val_acc improved from 0.85420 to 0.85430, saving model to saved_model.hdf5
# Epoch 17/100
#
# Epoch 00017: LearningRateScheduler setting learning rate to 0.000491481.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.2408 - acc: 0.9142 - val_loss: 0.4931 - val_acc: 0.8627
#
# Epoch 00017: val_acc improved from 0.85430 to 0.86270, saving model to saved_model.hdf5
# Epoch 18/100
#
# Epoch 00018: LearningRateScheduler setting learning rate to 0.0004670715.
# 195/195 [==============================] - 28s 143ms/step - loss: 0.2360 - acc: 0.9161 - val_loss: 0.5091 - val_acc: 0.8595
#
# Epoch 00018: val_acc did not improve from 0.86270
# Epoch 19/100
#
# Epoch 00019: LearningRateScheduler setting learning rate to 0.0004449718.
# 195/195 [==============================] - 28s 143ms/step - loss: 0.2346 - acc: 0.9171 - val_loss: 0.4942 - val_acc: 0.8579
#
# Epoch 00019: val_acc did not improve from 0.86270
# Epoch 20/100
#
# Epoch 00020: LearningRateScheduler setting learning rate to 0.000424869.
# 195/195 [==============================] - 28s 143ms/step - loss: 0.2280 - acc: 0.9197 - val_loss: 0.5249 - val_acc: 0.8557
#
# Epoch 00020: val_acc did not improve from 0.86270
# Epoch 21/100
#
# Epoch 00021: LearningRateScheduler setting learning rate to 0.0004065041.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.2250 - acc: 0.9199 - val_loss: 0.5019 - val_acc: 0.8599
#
# Epoch 00021: val_acc did not improve from 0.86270
# Epoch 22/100
#
# Epoch 00022: LearningRateScheduler setting learning rate to 0.000389661.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.2309 - acc: 0.9188 - val_loss: 0.5188 - val_acc: 0.8570
#
# Epoch 00022: val_acc did not improve from 0.86270
# Epoch 23/100
#
# Epoch 00023: LearningRateScheduler setting learning rate to 0.0003741581.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.2196 - acc: 0.9217 - val_loss: 0.5020 - val_acc: 0.8624
#
# Epoch 00023: val_acc did not improve from 0.86270
# Epoch 24/100
#
# Epoch 00024: LearningRateScheduler setting learning rate to 0.0003598417.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.2213 - acc: 0.9215 - val_loss: 0.4991 - val_acc: 0.8646
#
# Epoch 00024: val_acc improved from 0.86270 to 0.86460, saving model to saved_model.hdf5
# Epoch 25/100
#
# Epoch 00025: LearningRateScheduler setting learning rate to 0.0003465804.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.2182 - acc: 0.9218 - val_loss: 0.5037 - val_acc: 0.8627
#
# Epoch 00025: val_acc did not improve from 0.86460
# Epoch 26/100
#
# Epoch 00026: LearningRateScheduler setting learning rate to 0.0003342618.
# 195/195 [==============================] - 28s 143ms/step - loss: 0.2142 - acc: 0.9240 - val_loss: 0.5148 - val_acc: 0.8581
#
# Epoch 00026: val_acc did not improve from 0.86460
# Epoch 27/100
#
# Epoch 00027: LearningRateScheduler setting learning rate to 0.0003227889.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.2170 - acc: 0.9236 - val_loss: 0.4963 - val_acc: 0.8638
#
# Epoch 00027: val_acc did not improve from 0.86460
# Epoch 28/100
#
# Epoch 00028: LearningRateScheduler setting learning rate to 0.0003120774.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.2162 - acc: 0.9237 - val_loss: 0.4971 - val_acc: 0.8645
#
# Epoch 00028: val_acc did not improve from 0.86460
# Epoch 29/100
#
# Epoch 00029: LearningRateScheduler setting learning rate to 0.000302054.
# 195/195 [==============================] - 28s 143ms/step - loss: 0.2103 - acc: 0.9251 - val_loss: 0.4943 - val_acc: 0.8656
#
# Epoch 00029: val_acc improved from 0.86460 to 0.86560, saving model to saved_model.hdf5
# Epoch 30/100
#
# Epoch 00030: LearningRateScheduler setting learning rate to 0.0002926544.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.2158 - acc: 0.9239 - val_loss: 0.5092 - val_acc: 0.8589
#
# Epoch 00030: val_acc did not improve from 0.86560
# Epoch 31/100
#
# Epoch 00031: LearningRateScheduler setting learning rate to 0.0002838221.
# 195/195 [==============================] - 28s 143ms/step - loss: 0.2109 - acc: 0.9252 - val_loss: 0.4961 - val_acc: 0.8623
#
# Epoch 00031: val_acc did not improve from 0.86560
# Epoch 32/100
#
# Epoch 00032: LearningRateScheduler setting learning rate to 0.0002755074.
# 195/195 [==============================] - 28s 143ms/step - loss: 0.2103 - acc: 0.9268 - val_loss: 0.4937 - val_acc: 0.8648
#
# Epoch 00032: val_acc did not improve from 0.86560
# Epoch 33/100
#
# Epoch 00033: LearningRateScheduler setting learning rate to 0.000267666.
# 195/195 [==============================] - 28s 143ms/step - loss: 0.2077 - acc: 0.9256 - val_loss: 0.4829 - val_acc: 0.8681
#
# Epoch 00033: val_acc improved from 0.86560 to 0.86810, saving model to saved_model.hdf5
# Epoch 34/100
#
# Epoch 00034: LearningRateScheduler setting learning rate to 0.0002602585.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.2011 - acc: 0.9279 - val_loss: 0.4970 - val_acc: 0.8648
#
# Epoch 00034: val_acc did not improve from 0.86810
# Epoch 35/100
#
# Epoch 00035: LearningRateScheduler setting learning rate to 0.00025325.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.1995 - acc: 0.9300 - val_loss: 0.4991 - val_acc: 0.8656
#
# Epoch 00035: val_acc did not improve from 0.86810
# Epoch 36/100
#
# Epoch 00036: LearningRateScheduler setting learning rate to 0.0002466091.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.2039 - acc: 0.9285 - val_loss: 0.5007 - val_acc: 0.8649
#
# Epoch 00036: val_acc did not improve from 0.86810
# Epoch 37/100
#
# Epoch 00037: LearningRateScheduler setting learning rate to 0.0002403076.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.2028 - acc: 0.9292 - val_loss: 0.5147 - val_acc: 0.8606
#
# Epoch 00037: val_acc did not improve from 0.86810
# Epoch 38/100
#
# Epoch 00038: LearningRateScheduler setting learning rate to 0.0002343201.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.1972 - acc: 0.9308 - val_loss: 0.4873 - val_acc: 0.8687
#
# Epoch 00038: val_acc improved from 0.86810 to 0.86870, saving model to saved_model.hdf5
# Epoch 39/100
#
# Epoch 00039: LearningRateScheduler setting learning rate to 0.0002286237.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.2043 - acc: 0.9274 - val_loss: 0.4984 - val_acc: 0.8666
#
# Epoch 00039: val_acc did not improve from 0.86870
# Epoch 40/100
#
# Epoch 00040: LearningRateScheduler setting learning rate to 0.0002231977.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.1944 - acc: 0.9298 - val_loss: 0.5005 - val_acc: 0.8652
#
# Epoch 00040: val_acc did not improve from 0.86870
# Epoch 41/100
#
# Epoch 00041: LearningRateScheduler setting learning rate to 0.0002180233.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.1982 - acc: 0.9314 - val_loss: 0.4962 - val_acc: 0.8669
#
# Epoch 00041: val_acc did not improve from 0.86870
# Epoch 42/100
#
# Epoch 00042: LearningRateScheduler setting learning rate to 0.0002130833.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.1992 - acc: 0.9302 - val_loss: 0.5024 - val_acc: 0.8649
#
# Epoch 00042: val_acc did not improve from 0.86870
# Epoch 43/100
#
# Epoch 00043: LearningRateScheduler setting learning rate to 0.0002083623.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.1964 - acc: 0.9313 - val_loss: 0.5028 - val_acc: 0.8648
#
# Epoch 00043: val_acc did not improve from 0.86870
# Epoch 44/100
#
# Epoch 00044: LearningRateScheduler setting learning rate to 0.0002038459.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.1898 - acc: 0.9332 - val_loss: 0.4968 - val_acc: 0.8657
#
# Epoch 00044: val_acc did not improve from 0.86870
# Epoch 45/100
#
# Epoch 00045: LearningRateScheduler setting learning rate to 0.0001995211.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.1945 - acc: 0.9324 - val_loss: 0.5086 - val_acc: 0.8624
#
# Epoch 00045: val_acc did not improve from 0.86870
# Epoch 46/100
#
# Epoch 00046: LearningRateScheduler setting learning rate to 0.0001953761.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.1940 - acc: 0.9319 - val_loss: 0.5033 - val_acc: 0.8662
#
# Epoch 00046: val_acc did not improve from 0.86870
# Epoch 47/100
#
# Epoch 00047: LearningRateScheduler setting learning rate to 0.0001913998.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.1926 - acc: 0.9308 - val_loss: 0.5015 - val_acc: 0.8661
#
# Epoch 00047: val_acc did not improve from 0.86870
# Epoch 48/100
#
# Epoch 00048: LearningRateScheduler setting learning rate to 0.0001875821.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.1905 - acc: 0.9321 - val_loss: 0.5012 - val_acc: 0.8657
#
# Epoch 00048: val_acc did not improve from 0.86870
# Epoch 49/100
#
# Epoch 00049: LearningRateScheduler setting learning rate to 0.0001839137.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.1886 - acc: 0.9330 - val_loss: 0.5037 - val_acc: 0.8675
#
# Epoch 00049: val_acc did not improve from 0.86870
# Epoch 50/100
#
# Epoch 00050: LearningRateScheduler setting learning rate to 0.000180386.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.1903 - acc: 0.9326 - val_loss: 0.5116 - val_acc: 0.8666
#
# Epoch 00050: val_acc did not improve from 0.86870
# Epoch 51/100
#
# Epoch 00051: LearningRateScheduler setting learning rate to 0.0001769912.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.1878 - acc: 0.9344 - val_loss: 0.5027 - val_acc: 0.8664
#
# Epoch 00051: val_acc did not improve from 0.86870
# Epoch 52/100
#
# Epoch 00052: LearningRateScheduler setting learning rate to 0.0001737217.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.1868 - acc: 0.9348 - val_loss: 0.5016 - val_acc: 0.8662
#
# Epoch 00052: val_acc did not improve from 0.86870
# Epoch 53/100
#
# Epoch 00053: LearningRateScheduler setting learning rate to 0.0001705708.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.1845 - acc: 0.9344 - val_loss: 0.4999 - val_acc: 0.8682
#
# Epoch 00053: val_acc did not improve from 0.86870
# Epoch 54/100
#
# Epoch 00054: LearningRateScheduler setting learning rate to 0.0001675322.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.1851 - acc: 0.9349 - val_loss: 0.4992 - val_acc: 0.8654
#
# Epoch 00054: val_acc did not improve from 0.86870
# Epoch 55/100
#
# Epoch 00055: LearningRateScheduler setting learning rate to 0.0001646.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.1844 - acc: 0.9350 - val_loss: 0.5040 - val_acc: 0.8670
#
# Epoch 00055: val_acc did not improve from 0.86870
# Epoch 56/100
#
# Epoch 00056: LearningRateScheduler setting learning rate to 0.0001617687.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.1880 - acc: 0.9344 - val_loss: 0.5043 - val_acc: 0.8664
#
# Epoch 00056: val_acc did not improve from 0.86870
# Epoch 57/100
#
# Epoch 00057: LearningRateScheduler setting learning rate to 0.0001590331.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.1780 - acc: 0.9367 - val_loss: 0.5057 - val_acc: 0.8677
#
# Epoch 00057: val_acc did not improve from 0.86870
# Epoch 58/100
#
# Epoch 00058: LearningRateScheduler setting learning rate to 0.0001563885.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.1855 - acc: 0.9352 - val_loss: 0.4990 - val_acc: 0.8704
#
# Epoch 00058: val_acc improved from 0.86870 to 0.87040, saving model to saved_model.hdf5
# Epoch 59/100
#
# Epoch 00059: LearningRateScheduler setting learning rate to 0.0001538304.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.1814 - acc: 0.9358 - val_loss: 0.5002 - val_acc: 0.8675
#
# Epoch 00059: val_acc did not improve from 0.87040
# Epoch 60/100
#
# Epoch 00060: LearningRateScheduler setting learning rate to 0.0001513546.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.1834 - acc: 0.9354 - val_loss: 0.5066 - val_acc: 0.8690
#
# Epoch 00060: val_acc did not improve from 0.87040
# Epoch 61/100
#
# Epoch 00061: LearningRateScheduler setting learning rate to 0.0001489573.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.1794 - acc: 0.9378 - val_loss: 0.4993 - val_acc: 0.8675
#
# Epoch 00061: val_acc did not improve from 0.87040
# Epoch 62/100
#
# Epoch 00062: LearningRateScheduler setting learning rate to 0.0001466347.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.1792 - acc: 0.9375 - val_loss: 0.5014 - val_acc: 0.8672
#
# Epoch 00062: val_acc did not improve from 0.87040
# Epoch 63/100
#
# Epoch 00063: LearningRateScheduler setting learning rate to 0.0001443835.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.1787 - acc: 0.9376 - val_loss: 0.4966 - val_acc: 0.8680
#
# Epoch 00063: val_acc did not improve from 0.87040
# Epoch 64/100
#
# Epoch 00064: LearningRateScheduler setting learning rate to 0.0001422003.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.1770 - acc: 0.9374 - val_loss: 0.5121 - val_acc: 0.8673
#
# Epoch 00064: val_acc did not improve from 0.87040
# Epoch 65/100
#
# Epoch 00065: LearningRateScheduler setting learning rate to 0.0001400822.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.1862 - acc: 0.9344 - val_loss: 0.5113 - val_acc: 0.8677
#
# Epoch 00065: val_acc did not improve from 0.87040
# Epoch 66/100
#
# Epoch 00066: LearningRateScheduler setting learning rate to 0.0001380262.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.1785 - acc: 0.9373 - val_loss: 0.5035 - val_acc: 0.8695
#
# Epoch 00066: val_acc did not improve from 0.87040
# Epoch 67/100
#
# Epoch 00067: LearningRateScheduler setting learning rate to 0.0001360297.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.1745 - acc: 0.9381 - val_loss: 0.5040 - val_acc: 0.8688
#
# Epoch 00067: val_acc did not improve from 0.87040
# Epoch 68/100
#
# Epoch 00068: LearningRateScheduler setting learning rate to 0.0001340902.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.1732 - acc: 0.9384 - val_loss: 0.5027 - val_acc: 0.8699
#
# Epoch 00068: val_acc did not improve from 0.87040
# Epoch 69/100
#
# Epoch 00069: LearningRateScheduler setting learning rate to 0.0001322052.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.1809 - acc: 0.9368 - val_loss: 0.5067 - val_acc: 0.8687
#
# Epoch 00069: val_acc did not improve from 0.87040
# Epoch 70/100
#
# Epoch 00070: LearningRateScheduler setting learning rate to 0.0001303724.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.1763 - acc: 0.9371 - val_loss: 0.4925 - val_acc: 0.8697
#
# Epoch 00070: val_acc did not improve from 0.87040
# Epoch 71/100
#
# Epoch 00071: LearningRateScheduler setting learning rate to 0.0001285898.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.1761 - acc: 0.9382 - val_loss: 0.5103 - val_acc: 0.8682
#
# Epoch 00071: val_acc did not improve from 0.87040
# Epoch 72/100
#
# Epoch 00072: LearningRateScheduler setting learning rate to 0.0001268553.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.1743 - acc: 0.9391 - val_loss: 0.5055 - val_acc: 0.8683
#
# Epoch 00072: val_acc did not improve from 0.87040
# Epoch 73/100
#
# Epoch 00073: LearningRateScheduler setting learning rate to 0.0001251669.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.1750 - acc: 0.9384 - val_loss: 0.5015 - val_acc: 0.8698
#
# Epoch 00073: val_acc did not improve from 0.87040
# Epoch 74/100
#
# Epoch 00074: LearningRateScheduler setting learning rate to 0.0001235229.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.1753 - acc: 0.9372 - val_loss: 0.5020 - val_acc: 0.8690
#
# Epoch 00074: val_acc did not improve from 0.87040
# Epoch 75/100
#
# Epoch 00075: LearningRateScheduler setting learning rate to 0.0001219215.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.1738 - acc: 0.9390 - val_loss: 0.4996 - val_acc: 0.8693
#
# Epoch 00075: val_acc did not improve from 0.87040
# Epoch 76/100
#
# Epoch 00076: LearningRateScheduler setting learning rate to 0.0001203611.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.1737 - acc: 0.9393 - val_loss: 0.5091 - val_acc: 0.8678
#
# Epoch 00076: val_acc did not improve from 0.87040
# Epoch 77/100
#
# Epoch 00077: LearningRateScheduler setting learning rate to 0.0001188401.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.1775 - acc: 0.9380 - val_loss: 0.5014 - val_acc: 0.8678
#
# Epoch 00077: val_acc did not improve from 0.87040
# Epoch 78/100
#
# Epoch 00078: LearningRateScheduler setting learning rate to 0.0001173571.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.1752 - acc: 0.9390 - val_loss: 0.5026 - val_acc: 0.8688
#
# Epoch 00078: val_acc did not improve from 0.87040
# Epoch 79/100
#
# Epoch 00079: LearningRateScheduler setting learning rate to 0.0001159107.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.1698 - acc: 0.9405 - val_loss: 0.5127 - val_acc: 0.8673
#
# Epoch 00079: val_acc did not improve from 0.87040
# Epoch 80/100
#
# Epoch 00080: LearningRateScheduler setting learning rate to 0.0001144994.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.1772 - acc: 0.9381 - val_loss: 0.5031 - val_acc: 0.8675
#
# Epoch 00080: val_acc did not improve from 0.87040
# Epoch 81/100
#
# Epoch 00081: LearningRateScheduler setting learning rate to 0.0001131222.
# 195/195 [==============================] - 28s 143ms/step - loss: 0.1754 - acc: 0.9385 - val_loss: 0.5083 - val_acc: 0.8678
#
# Epoch 00081: val_acc did not improve from 0.87040
# Epoch 82/100
#
# Epoch 00082: LearningRateScheduler setting learning rate to 0.0001117776.
# 195/195 [==============================] - 28s 143ms/step - loss: 0.1712 - acc: 0.9398 - val_loss: 0.4958 - val_acc: 0.8695
#
# Epoch 00082: val_acc did not improve from 0.87040
# Epoch 83/100
#
# Epoch 00083: LearningRateScheduler setting learning rate to 0.0001104647.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.1729 - acc: 0.9401 - val_loss: 0.5024 - val_acc: 0.8687
#
# Epoch 00083: val_acc did not improve from 0.87040
# Epoch 84/100
#
# Epoch 00084: LearningRateScheduler setting learning rate to 0.0001091822.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.1725 - acc: 0.9403 - val_loss: 0.4991 - val_acc: 0.8682
#
# Epoch 00084: val_acc did not improve from 0.87040
# Epoch 85/100
#
# Epoch 00085: LearningRateScheduler setting learning rate to 0.0001079292.
# 195/195 [==============================] - 28s 143ms/step - loss: 0.1676 - acc: 0.9414 - val_loss: 0.5046 - val_acc: 0.8679
#
# Epoch 00085: val_acc did not improve from 0.87040
# Epoch 86/100
#
# Epoch 00086: LearningRateScheduler setting learning rate to 0.0001067046.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.1679 - acc: 0.9410 - val_loss: 0.5010 - val_acc: 0.8692
#
# Epoch 00086: val_acc did not improve from 0.87040
# Epoch 87/100
#
# Epoch 00087: LearningRateScheduler setting learning rate to 0.0001055075.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.1711 - acc: 0.9400 - val_loss: 0.5062 - val_acc: 0.8669
#
# Epoch 00087: val_acc did not improve from 0.87040
# Epoch 88/100
#
# Epoch 00088: LearningRateScheduler setting learning rate to 0.0001043369.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.1740 - acc: 0.9395 - val_loss: 0.4963 - val_acc: 0.8685
#
# Epoch 00088: val_acc did not improve from 0.87040
# Epoch 89/100
#
# Epoch 00089: LearningRateScheduler setting learning rate to 0.0001031921.
# 195/195 [==============================] - 28s 143ms/step - loss: 0.1677 - acc: 0.9419 - val_loss: 0.5011 - val_acc: 0.8683
#
# Epoch 00089: val_acc did not improve from 0.87040
# Epoch 90/100
#
# Epoch 00090: LearningRateScheduler setting learning rate to 0.0001020721.
# 195/195 [==============================] - 28s 143ms/step - loss: 0.1735 - acc: 0.9396 - val_loss: 0.4961 - val_acc: 0.8700
#
# Epoch 00090: val_acc did not improve from 0.87040
# Epoch 91/100
#
# Epoch 00091: LearningRateScheduler setting learning rate to 0.0001009761.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.1688 - acc: 0.9412 - val_loss: 0.5017 - val_acc: 0.8674
#
# Epoch 00091: val_acc did not improve from 0.87040
# Epoch 92/100
#
# Epoch 00092: LearningRateScheduler setting learning rate to 9.99034e-05.
# 195/195 [==============================] - 28s 143ms/step - loss: 0.1705 - acc: 0.9412 - val_loss: 0.5008 - val_acc: 0.8690
#
# Epoch 00092: val_acc did not improve from 0.87040
# Epoch 93/100
#
# Epoch 00093: LearningRateScheduler setting learning rate to 9.88533e-05.
# 195/195 [==============================] - 28s 143ms/step - loss: 0.1680 - acc: 0.9404 - val_loss: 0.5020 - val_acc: 0.8689
#
# Epoch 00093: val_acc did not improve from 0.87040
# Epoch 94/100
#
# Epoch 00094: LearningRateScheduler setting learning rate to 9.7825e-05.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.1719 - acc: 0.9386 - val_loss: 0.5015 - val_acc: 0.8682
#
# Epoch 00094: val_acc did not improve from 0.87040
# Epoch 95/100
#
# Epoch 00095: LearningRateScheduler setting learning rate to 9.68179e-05.
# 195/195 [==============================] - 28s 143ms/step - loss: 0.1703 - acc: 0.9401 - val_loss: 0.5059 - val_acc: 0.8701
#
# Epoch 00095: val_acc did not improve from 0.87040
# Epoch 96/100
#
# Epoch 00096: LearningRateScheduler setting learning rate to 9.58313e-05.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.1681 - acc: 0.9412 - val_loss: 0.4990 - val_acc: 0.8693
#
# Epoch 00096: val_acc did not improve from 0.87040
# Epoch 97/100
#
# Epoch 00097: LearningRateScheduler setting learning rate to 9.48647e-05.
# 195/195 [==============================] - 28s 143ms/step - loss: 0.1701 - acc: 0.9408 - val_loss: 0.5032 - val_acc: 0.8694
#
# Epoch 00097: val_acc did not improve from 0.87040
# Epoch 98/100
#
# Epoch 00098: LearningRateScheduler setting learning rate to 9.39173e-05.
# 195/195 [==============================] - 28s 143ms/step - loss: 0.1628 - acc: 0.9423 - val_loss: 0.5000 - val_acc: 0.8707
#
# Epoch 00098: val_acc improved from 0.87040 to 0.87070, saving model to saved_model.hdf5
# Epoch 99/100
#
# Epoch 00099: LearningRateScheduler setting learning rate to 9.29887e-05.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.1707 - acc: 0.9409 - val_loss: 0.5019 - val_acc: 0.8711
#
# Epoch 00099: val_acc improved from 0.87070 to 0.87110, saving model to saved_model.hdf5
# Epoch 100/100
#
# Epoch 00100: LearningRateScheduler setting learning rate to 9.20782e-05.
# 195/195 [==============================] - 28s 142ms/step - loss: 0.1632 - acc: 0.9429 - val_loss: 0.5011 - val_acc: 0.8704
#
# Epoch 00100: val_acc did not improve from 0.87110
# Model took 2779.49 seconds to train

# %%
score = model.evaluate(test_features, test_labels, batch_size=128)
print (score[1])
# Out:
# 10000/10000 [==============================] - 2s 167us/step
# 0.8704

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_12 (Conv2D)           (None, 32, 32, 32)        896
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 32, 32, 68)        19652
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 32, 32, 68)        272
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 32, 32, 68)        0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 32, 32, 136)       83368
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 32, 32, 136)       544
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 32, 32, 136)       0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 32, 32, 32)        4384
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 16, 16, 68)        19652
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 16, 16, 68)        272
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 16, 16, 68)        0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 16, 16, 136)       83368
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 16, 16, 136)       544
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 16, 16, 136)       0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 16, 16, 32)        4384
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 8, 8, 68)          19652
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 8, 8, 68)          272
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 8, 8, 68)          0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 8, 8, 136)         83368
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 8, 8, 136)         544
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 8, 8, 136)         0
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 8, 8, 10)          1370
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 1, 1, 10)          6410
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 10)                0
# _________________________________________________________________
# activation_2 (Activation)    (None, 10)                0
# =================================================================
# Total params: 329,080
# Trainable params: 327,792
# Non-trainable params: 1,288
# _________________________________________________________________

# %% [markdown]
# ### Grad CAM result with Cutout

# %%
import cv2
from google.colab.patches import cv2_imshow

images = [100,101,201,510,600,1000,1600,1601,3000,4000,5500,7000,7500,8000,9000,9999]
for j in images:
  x = testX[j]
  x = np.expand_dims(x, axis=0)
  preds = model.predict(x,batch_size=1)
  class_idx = np.argmax(preds[0])
  class_output = model.output[:, class_idx]
  last_conv_layer = model.get_layer("conv2d_20")

  grads = K.gradients(class_output, last_conv_layer.output)[0]
  pooled_grads = K.mean(grads, axis=(0, 1, 2))
  iterate = K.function([model.input], [pooled_grads, last_conv_layer.output[0]])
  pooled_grads_value, conv_layer_output_value = iterate([x])
  for i in range(136):
    conv_layer_output_value[:, :, i] *= pooled_grads_value[i]
    
  heatmap = np.mean(conv_layer_output_value, axis=-1)
  heatmap = np.maximum(heatmap, 0)
  heatmap /= np.max(heatmap) 
  img = (testX[j])
  heatmap = cv2.resize(heatmap, (img.shape[1], img.shape[0]))
  heatmap = np.uint8(255 * heatmap)
  heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)
  superimposed_img = cv2.addWeighted(img, 0.6, heatmap, 0.4, 0)

  concatimg = cv2.hconcat([img,superimposed_img])
 
  print (j)
  cv2_imshow(concatimg)
  cv2.waitKey(0)
  print (" ")
  j = j + 1
# Out:
# 100
# <PIL.Image.Image image mode=RGB size=64x32 at 0x7FD317B5E588>
#
# 101
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:22: RuntimeWarning: invalid value encountered in true_divide
# <PIL.Image.Image image mode=RGB size=64x32 at 0x7FD315FF74A8>
#
# 201
# <PIL.Image.Image image mode=RGB size=64x32 at 0x7FD440AA5F98>
#
# 510
# <PIL.Image.Image image mode=RGB size=64x32 at 0x7FD440AB4D68>
#
# 600
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:22: RuntimeWarning: invalid value encountered in true_divide
# <PIL.Image.Image image mode=RGB size=64x32 at 0x7FD315FF7048>
#
# 1000
# <PIL.Image.Image image mode=RGB size=64x32 at 0x7FD440153F28>
#
# 1600
# <PIL.Image.Image image mode=RGB size=64x32 at 0x7FD317B32630>
#
# 1601
# <PIL.Image.Image image mode=RGB size=64x32 at 0x7FD3180EF828>
#
# 3000
# <PIL.Image.Image image mode=RGB size=64x32 at 0x7FD44091CDD8>
#
# 4000
# <PIL.Image.Image image mode=RGB size=64x32 at 0x7FD4408EC9B0>
#
# 5500
# <PIL.Image.Image image mode=RGB size=64x32 at 0x7FD440983A90>
#
# 7000
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:22: RuntimeWarning: invalid value encountered in true_divide
# <PIL.Image.Image image mode=RGB size=64x32 at 0x7FD4408BFAC8>
#
# 7500
# <PIL.Image.Image image mode=RGB size=64x32 at 0x7FD4407B14E0>
#
# 8000
# <PIL.Image.Image image mode=RGB size=64x32 at 0x7FD4408BFAC8>
#
# 9000
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:22: RuntimeWarning: invalid value encountered in true_divide
# <PIL.Image.Image image mode=RGB size=64x32 at 0x7FD440612DD8>
#
# 9999
# <PIL.Image.Image image mode=RGB size=64x32 at 0x7FD315F06E80>
